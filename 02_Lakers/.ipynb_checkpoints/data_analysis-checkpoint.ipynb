# %% [markdown]
# # 데이터 불러오기

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# math
import math

# %%
# 경고 메세지 무시하기

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("./lakers.csv", encoding="cp949")
df.head()
# Out:
#        date opponent game_type   time  period      etype team  \
# 0  20081028      POR      home  12:00       1  jump ball  OFF
# 1  20081028      POR      home  11:39       1       shot  LAL
# 2  20081028      POR      home  11:37       1    rebound  LAL
# 3  20081028      POR      home  11:25       1       shot  LAL
# 4  20081028      POR      home  11:23       1    rebound  LAL
#
#                 player  result  points   type     x     y
# 0                  NaN     NaN       0    NaN   NaN   NaN
# 1            Pau Gasol  missed       0   hook  23.0  13.0
# 2  Vladimir Radmanovic     NaN       0    off   NaN   NaN
# 3         Derek Fisher  missed       0  layup  25.0   6.0
# 4            Pau Gasol     NaN       0    off   NaN   NaN

# %%
df_copy=df.copy()
df_copy.head()
# Out:
#        date opponent game_type   time  period      etype team  \
# 0  20081028      POR      home  12:00       1  jump ball  OFF
# 1  20081028      POR      home  11:39       1       shot  LAL
# 2  20081028      POR      home  11:37       1    rebound  LAL
# 3  20081028      POR      home  11:25       1       shot  LAL
# 4  20081028      POR      home  11:23       1    rebound  LAL
#
#                 player  result  points   type     x     y
# 0                  NaN     NaN       0    NaN   NaN   NaN
# 1            Pau Gasol  missed       0   hook  23.0  13.0
# 2  Vladimir Radmanovic     NaN       0    off   NaN   NaN
# 3         Derek Fisher  missed       0  layup  25.0   6.0
# 4            Pau Gasol     NaN       0    off   NaN   NaN

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# <칼럼 설명>
#
# * data : 경기 일자
# * opponent : 대전 팀
# * game_type : 홈 경기 vs 원정 경기
# * time : 분:초
# * period : 쿼터 (한 쿼터 당 12분 씩, 동점인 경우 5 쿼터 진행)
# * etype : 유형
# * team : 팀 구분 (LAL : LA Lakers, 상대 팀)
# * player : 선수명
# * result : 결과
# * points : 점수
# * type : 세부 행동
# * x, y : 상대편 팀 골대 뒤에서 바라본 x, y 좌표, 골대의 위치는 (25, 5, 25) 이다.

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34624 entries, 0 to 34623
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       34624 non-null  int64
#  1   opponent   34624 non-null  object
#  2   game_type  34624 non-null  object
#  3   time       34624 non-null  object
#  4   period     34624 non-null  int64
#  5   etype      34624 non-null  object
#  6   team       34624 non-null  object
#  7   player     29231 non-null  object
#  8   result     16888 non-null  object
#  9   points     34624 non-null  int64
#  10  type       24242 non-null  object
#  11  x          13067 non-null  float64
#  12  y          13067 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 3.4+ MB

# %%
df_copy.isnull().sum()
# Out:
# date             0
# opponent         0
# game_type        0
# time             0
# period           0
# etype            0
# team             0
# player        5393
# result       17736
# points           0
# type         10382
# x            21557
# y            21557
# dtype: int64

# %% [markdown]
# <범주형 변수 vs 연속형 변수>
#
# * 범주형 변수 (빈도 계산 가능)
#
# ```opponent, game_type, etype, team, player, type, period, result```
#
# * 연속형 변수 (수치 계산 가능)
#
# ```시간 변수 (date, time), points, x, y```

# %% [markdown]
# * 무조건 숫자라고 해서 연속형 변수는 아니다.
# * (예시) period, 평균 또는 표준 편차 구할 이유가 없다.

# %%
df_copy.describe()
# Out:
#                date        period        points             x             y
# count  3.462400e+04  34624.000000  34624.000000  13067.000000  13067.000000
# mean   2.008694e+07      2.535524      0.462714     25.317670     13.430550
# std    4.372405e+03      1.124725      0.849231     11.185946      8.665827
# min    2.008103e+07      1.000000      0.000000      0.000000      3.000000
# 25%    2.008121e+07      2.000000      0.000000     20.000000      6.000000
# 50%    2.009012e+07      3.000000      0.000000     25.000000     10.000000
# 75%    2.009031e+07      4.000000      1.000000     31.000000     20.000000
# max    2.009041e+07      5.000000      3.000000     51.000000     90.000000

# %%
df_copy.describe(include=object)
# Out:
#        opponent game_type   time  etype   team       player result   type
# count     34624     34624  34624  34624  34624        29231  16888  24242
# unique       29         2    717     10     31          370      2     73
# top         DEN      home   0:00   shot    LAL  Kobe Bryant   made    def
# freq       1855     17471    357  13108  17235         2945   8916   4768

# %%
print(f'Opponent : {df_copy["opponent"].unique()}')
print(f'Game Type : {df_copy["game_type"].unique()}')
print(f'Etype : {df_copy["etype"].unique()}')
print(f'Team : {df_copy["team"].unique()}')
print(f'Result : {df_copy["result"].unique()}')
print(f'Type : {df_copy["type"].unique()}')
# Out:
# Opponent : ['POR' 'LAC' 'DEN' 'HOU' 'DAL' 'DET' 'CHI' 'PHX' 'SAC' 'NJN' 'TOR' 'IND'
#  'PHI' 'WAS' 'MIL' 'MIN' 'NYK' 'MIA' 'ORL' 'MEM' 'NOH' 'BOS' 'UTA' 'GSW'
#  'SAS' 'CLE' 'OKC' 'ATL' 'CHA']
# Game Type : ['home' 'away']
# Etype : ['jump ball' 'shot' 'rebound' 'foul' 'free throw' 'turnover' 'timeout'
#  'sub' 'violation' 'ejection']
# Team : ['OFF' 'LAL' 'POR' 'LAC' 'DEN' 'HOU' 'DAL' 'DET' 'CHI' 'PHX' 'SAC' 'NJN'
#  'TOR' 'IND' 'PHI' 'WAS' 'MIL' 'MIN' 'NYK' 'MIA' 'ORL' 'MEM' 'NOH' 'BOS'
#  'UTA' 'GSW' 'SAS' 'CLE' 'OKC' 'ATL' 'CHA']
# Result : [nan 'missed' 'made']
# Type : [nan 'hook' 'off' 'layup' 'shooting' 'personal' 'jump' 'pullup jump' 'def'
#  'driving layup' 'driving finger roll layup' 'regular' 'offensive' '3pt'
#  'turnaround jump' 'putback layup' 'slam dunk' 'tip' 'dunk'
#  'defensive goaltending' 'hook bank' 'running layup' 'official'
#  'driving slam dunk' 'short' 'driving reverse layup' 'kicked ball'
#  'putback dunk' 'technical' 'alley oop dunk' 'turnaround fade away'
#  'running jump' 'delay of game' 'defense 3 second' 'fade away bank'
#  'floating jump' 'driving dunk' 'loose ball' 'running bank' 'running dunk'
#  'fade away jumper' 'finger roll layup' 'turnaround hook' 'reverse layup'
#  'reverse dunk' 'jump hook' 'jump bank' 'double technical' 'running hook'
#  'driving jump' 'turnaround bank' 'step back jump' 'turnaround bank hook'
#  'pullup bank' 'alley oop layup' 'putback slam dunk' 'flagrant type 1'
#  'running reverse layup' 'running finger roll layup' 'reverse slam dunk'
#  'hanging technical' 'running slam dunk' 'driving bank hook' 'jump ball'
#  'away from play' 'double personal' 'driving bank' 'running bank hook'
#  'driving hook' 'lane' 'clear path' 'jump bank hook' 'flagrant type 2'
#  'inbound']

# %%
print(f'Player : {df_copy["player"].unique()}')
# Out:
# Player : [nan 'Pau Gasol' 'Vladimir Radmanovic' 'Derek Fisher' 'Greg Oden'
#  'LaMarcus Aldridge' 'Kobe Bryant' 'Travis Outlaw' 'Andrew Bynum'
#  'Brandon Roy' 'Steve Blake' 'Joel Przybilla' 'Lamar Odom'
#  'Rudy Fernandez' 'Trevor Ariza' 'Jordan Farmar' 'Channing Frye'
#  'Sergio Rodriguez' 'Sasha Vujacic' 'Jerryd Bayless' 'Nicolas Batum'
#  'Luke Walton' 'Ike Diogu' 'Josh Powell' 'Chris Mihm' 'Chris Kaman'
#  'Baron Davis' 'Tim Thomas' 'Cuttino Mobley' 'Al Thornton' 'Brian Skinner'
#  'Jason Hart' 'Steve Novak' 'Eric Gordon' 'Ricky Davis' 'Mike Taylor'
#  'Paul Davis' 'Kenyon Martin' 'Carmelo Anthony' 'Allen Iverson'
#  'Nene Hilario' 'Anthony Carter' 'J.R. Smith' 'Chris Andersen'
#  'Linas Kleiza' 'Juwan Howard' 'Marcus Camby' 'Luis Scola' 'Ron Artest'
#  'Rafer Alston' 'Yao Ming' 'Tracy McGrady' 'Chuck Hayes' 'Aaron Brooks'
#  'Carl Landry' 'Brent Barry' 'Luther Head' 'Jason Terry' 'Erick Dampier'
#  'Gerald Green' 'Jason Kidd' 'Dirk Nowitzki' 'Jerry Stackhouse'
#  'Brandon Bass' 'Jose Juan Barea' 'DeSagana Diop' 'Antoine Wright'
#  'Kwame Brown' 'Richard Hamilton' 'Rasheed Wallace' 'Tayshaun Prince'
#  'Walter Herrmann' 'Rodney Stuckey' 'Arron Afflalo' 'Jason Maxiell'
#  'Drew Gooden' 'Derrick Rose' 'Joakim Noah' 'Ben Gordon' 'Luol Deng'
#  'Tyrus Thomas' 'Aaron Gray' 'Larry Hughes' 'Andres Nocioni'
#  'Lindsey Hunter' 'Cedric Simmons' 'Thabo Sefolosha' "Shaquille O'Neal"
#  'Amare Stoudemire' 'Raja Bell' 'Matt Barnes' 'Steve Nash' 'Boris Diaw'
#  'Sean Singletary' 'Grant Hill' 'Louis Amundson' 'Robin Lopez'
#  'Goran Dragic' 'Chauncey Billups' 'Dahntay Jones' 'Renaldo Balkman'
#  'Jason Thompson' 'Beno Udrih' 'John Salmons' 'Spencer Hawes'
#  'Brad Miller' 'Donte Greene' 'Bobby Jackson' 'Bobby Brown'
#  'Shelden Williams' 'Bobby Simmons' 'Vince Carter' 'Yi Jianlian'
#  'Brook Lopez' 'Devin Harris' 'Sean Williams' 'Jarvis Hayes'
#  'Ryan Anderson' 'Keyon Dooling' 'Trenton Hassell' 'Maurice Ager'
#  'Devean George' 'Carlisle' 'Chris Bosh' 'Jose Calderon' 'Jamario Moon'
#  'Andrea Bargnani' 'Anthony Parker' 'Jason Kapono' 'Joey Graham'
#  'Roko Ukic' 'Kris Humphries' 'Will Solomon' 'Hassan Adams' 'D.J. Mbenga'
#  'Rasho Nesterovic' 'Marquis Daniels' 'Troy Murphy' 'T.J. Ford'
#  'Danny Granger' 'Brandon Rush' 'Stephen Graham' 'Jarrett Jack'
#  'Roy Hibbert' 'Josh McRoberts' 'Andre Iguodala' 'Thaddeus Young'
#  'Samuel Dalembert' 'Andre Miller' 'Willie Green' 'Elton Brand'
#  'Lou Williams' 'Marreese Speights' 'Theo Ratliff' 'Royal Ivey'
#  'Caron Butler' 'Dee Brown' 'JaVale McGee' 'DeShawn Stevenson'
#  'Antawn Jamison' 'Andray Blatche' 'Darius Songaila' 'Etan Thomas'
#  'Antonio Daniels' 'Dominic McGuire' 'Nick Young' 'Richard Jefferson'
#  'Andrew Bogut' 'Michael Redd' 'Luke Ridnour' 'Malik Allen'
#  'Charlie Villanueva' 'Luc Richard Mbah a Moute' 'Skiles' 'Dan Gadzuric'
#  'Ramon Sessions' 'Joe Alexander' 'Francisco Elson' 'Tyronn Lue' 'Yue Sun'
#  'Francisco Garcia' 'Mikki Moore' 'Leandro Barbosa' 'Craig Smith'
#  'Mike Miller' 'Al Jefferson' 'Ryan Gomes' 'Randy Foye' 'Rashad McCants'
#  'Kevin Love' 'Rodney Carney' 'Sebastian Telfair' 'Chris Duhon'
#  'Al Harrington' 'Quentin Richardson' 'David Lee' 'Wilson Chandler'
#  'Nate Robinson' 'Dwyane Wade' 'Udonis Haslem' 'Mario Chalmers'
#  'Joel Anthony' 'Shawn Marion' 'Michael Beasley' 'Daequan Cook'
#  'Jamaal Magloire' 'Chris Quinn' 'Yakhouba Diawara' 'Jackson'
#  'Hedo Turkoglu' 'Jameer Nelson' 'Dwight Howard' 'Rashard Lewis'
#  'Keith Bogans' 'Mickael Pietrus' 'Marcin Gortat' 'Anthony Johnson'
#  'Courtney Lee' 'Brian Cook' 'Tony Battie' 'Marc Gasol' 'Darko Milicic'
#  'Rudy Gay' 'Kyle Lowry' 'O.J. Mayo' 'Hakim Warrick' 'Quinton Ross'
#  'Greg Buckner' 'Mike Conley' 'Tyson Chandler' 'Rasual Butler'
#  'David West' 'Devin Brown' 'Chris Paul' 'Morris Peterson' 'James Posey'
#  'Hilton Armstrong' 'Rajon Rondo' 'Ray Allen' 'Kevin Garnett'
#  'Paul Pierce' 'Kendrick Perkins' 'Eddie House' 'Tony Allen' 'Glen Davis'
#  'Leon Powe' 'Mehmet Okur' 'Paul Millsap' 'Ronnie Brewer' 'Deron Williams'
#  'C.J. Miles' 'Andrei Kirilenko' 'Matt Harpring' 'Brevin Knight'
#  'Kyle Korver' 'Jarron Collins' 'Kosta Koufos' 'Sloan' 'Sun Yue'
#  'Peja Stojakovic' 'Melvin Ely' 'Corey Maggette' 'Marco Belinelli'
#  'Brandan Wright' 'Jamal Crawford' 'Andris Biedrins' 'Rob Kurz'
#  'Ronny Turiaf' 'Kelenna Azubuike' 'C.J. Watson' 'Anthony Randolph'
#  'Mike Dunleavy' 'Travis Diener' 'Jeff Foster' 'James Jones' 'Von Wafer'
#  'Shane Battier' 'Dikembe Mutombo' 'Matt Bonner' 'Tim Duncan'
#  'Michael Finley' 'Tony Parker' 'Roger Mason' 'Manu Ginobili'
#  'George Hill' 'Kurt Thomas' 'Bruce Bowen' 'J.J. Redick'
#  'Anderson Varejao' 'LeBron James' 'Ben Wallace' 'Mo Williams'
#  'Sasha Pavlovic' 'J.J. Hickson' 'Lorenzen Wright' 'Daniel Gibson'
#  'Wally Szczerbiak' 'Mardy Collins' 'DeAndre Jordan' 'Fred Jones'
#  'Mike James' 'Javaris Crittenton' 'Oleksiy Pecherov' 'Fabricio Oberto'
#  'Ime Udoka' 'Austin Croshere' 'Brian Cardinal' 'Mark Madsen'
#  'Darrell Arthur' 'Darius Miles' 'Marko Jaric' 'Jared Jeffries'
#  'Danilo Gallinari' "Jermaine O'Neal" 'Zydrunas Ilgauskas'
#  'Russell Westbrook' 'Nick Collison' 'Jeff Green' 'Kevin Durant'
#  'Kyle Weaver' 'Nenad Krstic' 'Earl Watson' 'Joe Smith' 'Al Horford'
#  'Josh Smith' 'Mike Bibby' 'Marvin Williams' 'Joe Johnson' 'Zaza Pachulia'
#  'Maurice Evans' 'Solomon Jones' 'Acie Law' 'Adam Morrison' 'Mario West'
#  'Shannon Brown' 'Thomas Gardner' 'Stephen Jackson' 'Monta Ellis'
#  'Jermareo Davidson' 'Sean Marks' 'Jason Collins' 'Kevin Ollie'
#  'Alando Tucker' 'Jason Richardson' 'Jared Dudley' 'Johan Petro'
#  'James Singleton' 'Reggie Evans' 'Donyell Marshall' 'Anthony Morrow'
#  'Kirk Hinrich' 'Chucky Atkins' 'Malik Rose' 'Antonio McDyess'
#  'Will Bynum' 'Walter Sharpe' 'Amir Johnson' 'Josh Boone'
#  'Chris Douglas-Roberts' 'Ronald Murray' 'Gerald Wallace' 'Raymond Felton'
#  'Emeka Okafor' 'D.J. Augustin' 'Charlie Bell' 'James White'
#  'Zach Randolph' 'Hamed Haddadi' 'Carlos Boozer' 'Kyrylo Fesenko'
#  'Ronnie Price']

# %%
print(f'전체 데이터의 개수 : {df_copy.shape[0]*df_copy.shape[1]}')
print(f'전체 결측치의 개수 : {df_copy.isnull().sum().sum()}')
print(f'전체 데이터에서 결측치 비율 : {((df_copy.isnull().sum().sum())/(df_copy.shape[0]*df_copy.shape[1]))*100:.2f}%')
# Out:
# 전체 데이터의 개수 : 450112
# 전체 결측치의 개수 : 76625
# 전체 데이터에서 결측치 비율 : 17.02%

# %%
print(f'LA 팀 상대편 수 : {df_copy["opponent"].nunique()}')
print(f'경기 등장 행동 수 : {df_copy["etype"].nunique()}')
print(f'경기 등장 세부 행동 수 : {df_copy["type"].nunique()}')
# Out:
# LA 팀 상대편 수 : 29
# 경기 등장 행동 수 : 10
# 경기 등장 세부 행동 수 : 73

# %% [markdown]
# # 데이터에서 질문 만들기

# %% [markdown]
# * LAL 원정 경기와 홈 경기 비율?
# * 경기에서 선수들이 가장 많이 하는 행동 유형은?
# * 이번 시즌에서 LAL 경기 결과는?
# * LAL 선수들은 코트의 어떤 위치에서 어떤 동작을 하였는가?

# %% [markdown]
# # 데이터 정비하기

# %% [markdown]
# ## 시간 타입의 칼럼 정비하기

# %%
# date와 time을 하나의 칼럼으로 합쳐주기.
df_copy["date"]=df_copy["date"].astype(str)

# %%
df_copy["datetime"]=df_copy["date"]+" "+df_copy["time"]
df_copy.head()
# Out:
#        date opponent game_type   time  period      etype team  \
# 0  20081028      POR      home  12:00       1  jump ball  OFF
# 1  20081028      POR      home  11:39       1       shot  LAL
# 2  20081028      POR      home  11:37       1    rebound  LAL
# 3  20081028      POR      home  11:25       1       shot  LAL
# 4  20081028      POR      home  11:23       1    rebound  LAL
#
#                 player  result  points   type     x     y        datetime
# 0                  NaN     NaN       0    NaN   NaN   NaN  20081028 12:00
# 1            Pau Gasol  missed       0   hook  23.0  13.0  20081028 11:39
# 2  Vladimir Radmanovic     NaN       0    off   NaN   NaN  20081028 11:37
# 3         Derek Fisher  missed       0  layup  25.0   6.0  20081028 11:25
# 4            Pau Gasol     NaN       0    off   NaN   NaN  20081028 11:23

# %%
# 날짜 타입에 맞게 변경하기. (시계열 분석 시 매우 유용)
df_copy["datetime"]=pd.to_datetime(df_copy["datetime"], format='%Y%m%d %H:%M:%S')
df_copy["date"]=pd.to_datetime(df_copy["date"], format='%Y%m%d')

# %%
df_copy.head()
# Out:
#         date opponent game_type   time  period      etype team  \
# 0 2008-10-28      POR      home  12:00       1  jump ball  OFF
# 1 2008-10-28      POR      home  11:39       1       shot  LAL
# 2 2008-10-28      POR      home  11:37       1    rebound  LAL
# 3 2008-10-28      POR      home  11:25       1       shot  LAL
# 4 2008-10-28      POR      home  11:23       1    rebound  LAL
#
#                 player  result  points   type     x     y            datetime
# 0                  NaN     NaN       0    NaN   NaN   NaN 2008-10-28 12:00:00
# 1            Pau Gasol  missed       0   hook  23.0  13.0 2008-10-28 11:39:00
# 2  Vladimir Radmanovic     NaN       0    off   NaN   NaN 2008-10-28 11:37:00
# 3         Derek Fisher  missed       0  layup  25.0   6.0 2008-10-28 11:25:00
# 4            Pau Gasol     NaN       0    off   NaN   NaN 2008-10-28 11:23:00

# %% [markdown]
# ## 결측치 처리하기

# %%
# 칼럼 별 결측치의 유무 확인
df_copy.isnull().any(axis=0)
# Out:
# date         False
# opponent     False
# game_type    False
# time         False
# period       False
# etype        False
# team         False
# player        True
# result        True
# points       False
# type          True
# x             True
# y             True
# datetime     False
# dtype: bool

# %%
df_copy.isnull().sum()
# player, result, type은 특정한 값이기 때문에 결측치 안 채워도 좋다.
# x, y 또한 좌표이기 때문에 결측치 채우지 않아도 되지만, 0을 넣어 보도록 하자.
# 좌표계이기 때문에 0을 넣는다고 해서 크게 문제되지 않는다.
# Out:
# date             0
# opponent         0
# game_type        0
# time             0
# period           0
# etype            0
# team             0
# player        5393
# result       17736
# points           0
# type         10382
# x            21557
# y            21557
# datetime         0
# dtype: int64

# %%
# 하지만, 0을 넣기 전에 0이 있는지 확인해야 한다.
# 왜냐하면 실제 데이터가 0인 경우에는 결측치를 모두 0으로 변경 시 잘못된 결과를 가져올 수 있기 때문이다.
print(df_copy.index[df_copy["x"]==0].tolist())
print(df_copy.index[df_copy["x"]==-1].tolist())
print(df_copy.index[df_copy["y"]==0].tolist())
# Out:
# [203, 3636, 4205, 4272, 4474, 9407, 13882, 13890, 14484, 14992, 16488, 16955, 22606, 23761, 30173, 33921, 34053, 34517]
# []
# []

# %%
# 값이 존재하기 때문에 x=-1, y=0 넣어주기.
df_copy["x"]=df_copy["x"].fillna(-1)
df_copy["y"]=df_copy["y"].fillna(0)

# %% [markdown]
# # EDA & Visualization

# %% [markdown]
# ## LAL 홈 경기와 원정 경기 비율

# %%
# 각 날짜 별 경기 그룹화하기.
df_copy[["date", "game_type"]].groupby(["date", "game_type"]).sum()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2008-10-28 00:00:00, home), (2008-10-29 00:00:00, away), (2008-11-01 00:00:00, away), (2008-11-05 00:00:00, home), (2008-11-09 00:00:00, home), (2008-11-11 00:00:00, away), (2008-11-14 00:00:00, home), (2008-11-18 00:00:00, home), (2008-11-20 00:00:00, away), (2008-11-21 00:00:00, home), (2008-11-23 00:00:00, home), (2008-11-25 00:00:00, home), (2008-11-28 00:00:00, home), (2008-11-30 00:00:00, home), (2008-12-02 00:00:00, away), (2008-12-03 00:00:00, away), (2008-12-05 00:00:00, away), (2008-12-07 00:00:00, home), (2008-12-09 00:00:00, away), (2008-12-10 00:00:00, home), (2008-12-12 00:00:00, home), (2008-12-14 00:00:00, home), (2008-12-16 00:00:00, home), (2008-12-19 00:00:00, away), (2008-12-20 00:00:00, away), (2008-12-22 00:00:00, away), (2008-12-23 00:00:00, away), (2008-12-25 00:00:00, home), (2009-01-02 00:00:00, home), (2009-01-04 00:00:00, home), (2009-01-06 00:00:00, home), (2009-01-07 00:00:00, away), (2009-01-09 00:00:00, home), (2009-01-11 00:00:00, home), (2009-01-13 00:00:00, away), (2009-01-14 00:00:00, away), (2009-01-16 00:00:00, home), (2009-01-19 00:00:00, home), (2009-01-21 00:00:00, away), (2009-01-22 00:00:00, home), (2009-01-25 00:00:00, home), (2009-01-30 00:00:00, away), (2009-01-31 00:00:00, away), (2009-02-02 00:00:00, away), (2009-02-04 00:00:00, away), (2009-02-05 00:00:00, away), (2009-02-08 00:00:00, away), (2009-02-10 00:00:00, home), (2009-02-17 00:00:00, home), (2009-02-18 00:00:00, away), (2009-02-20 00:00:00, home), (2009-02-22 00:00:00, away), (2009-02-24 00:00:00, away), (2009-02-26 00:00:00, home), (2009-02-27 00:00:00, away), (2009-03-01 00:00:00, away), (2009-03-03 00:00:00, home), (2009-03-06 00:00:00, home), (2009-03-09 00:00:00, away), (2009-03-11 00:00:00, away), (2009-03-12 00:00:00, away), (2009-03-15 00:00:00, home), (2009-03-17 00:00:00, home), (2009-03-19 00:00:00, home), (2009-03-21 00:00:00, away), (2009-03-24 00:00:00, away), (2009-03-26 00:00:00, away), (2009-03-27 00:00:00, away), (2009-03-29 00:00:00, away), (2009-03-31 00:00:00, away), (2009-04-01 00:00:00, away), (2009-04-03 00:00:00, home), (2009-04-05 00:00:00, home), (2009-04-07 00:00:00, away), (2009-04-09 00:00:00, home), (2009-04-10 00:00:00, away), (2009-04-12 00:00:00, home), (2009-04-14 00:00:00, home)]
#
# [78 rows x 0 columns]

# %%
# as_index=False
df_copy[["date", "game_type"]].groupby(["date", "game_type"], as_index=False).sum()
# Out:
#          date game_type
# 0  2008-10-28      home
# 1  2008-10-29      away
# 2  2008-11-01      away
# 3  2008-11-05      home
# 4  2008-11-09      home
# ..        ...       ...
# 73 2009-04-07      away
# 74 2009-04-09      home
# 75 2009-04-10      away
# 76 2009-04-12      home
# 77 2009-04-14      home
#
# [78 rows x 2 columns]

# %%
# reset_index
df_copy[["date", "game_type"]].groupby(["date", "game_type"]).sum().reset_index()
# Out:
#          date game_type
# 0  2008-10-28      home
# 1  2008-10-29      away
# 2  2008-11-01      away
# 3  2008-11-05      home
# 4  2008-11-09      home
# ..        ...       ...
# 73 2009-04-07      away
# 74 2009-04-09      home
# 75 2009-04-10      away
# 76 2009-04-12      home
# 77 2009-04-14      home
#
# [78 rows x 2 columns]

# %%
# 지금은 홈 경기와 원정 경기의 비율만 알아볼 것이다. 그러니, 첫 번째 빼고 모두 날리는 방식 이용하기.
# drop_duplicate, keep="first"
df1=df_copy.drop_duplicates("date", keep="first")
df1.head()
# Out:
#            date opponent game_type   time  period      etype team player  \
# 0    2008-10-28      POR      home  12:00       1  jump ball  OFF    NaN
# 416  2008-10-29      LAC      away  12:00       1  jump ball  OFF    NaN
# 871  2008-11-01      DEN      away  12:00       1  jump ball  OFF    NaN
# 1364 2008-11-05      LAC      home  12:00       1  jump ball  OFF    NaN
# 1867 2008-11-09      HOU      home  12:00       1  jump ball  OFF    NaN
#
#      result  points type    x    y            datetime
# 0       NaN       0  NaN -1.0  0.0 2008-10-28 12:00:00
# 416     NaN       0  NaN -1.0  0.0 2008-10-29 12:00:00
# 871     NaN       0  NaN -1.0  0.0 2008-11-01 12:00:00
# 1364    NaN       0  NaN -1.0  0.0 2008-11-05 12:00:00
# 1867    NaN       0  NaN -1.0  0.0 2008-11-09 12:00:00

# %%
# 마이너스 깨짐 방지
plt.rc('font', family='NanumGothic')

# seaborn 배경색 설정
sns.set_style("darkgrid")

# 한글 깨짐 방지
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
fig, ax=plt.subplots(1, 2, figsize=(15, 7), dpi=200)
ax=ax.flatten()

# pie plot
_=df_copy["game_type"].value_counts().plot.pie(ax=ax[0], explode=[0, 0.1], 
                                               autopct="%.2f%%", shadow=True)
_=ax[0].set_ylabel("")
_=ax[0].set_title("원정 경기 vs 홈 경기")
_=ax[0].legend(fontsize=15)

# count plot
_=sns.countplot(data=df_copy, x="game_type", ax=ax[1])
_=ax[1].set_title("원정 경기 vs 홈 경기")
_=ax[1].set_ylabel("")

# %% [markdown]
# ## 경기에서 발생한 행동 유형 확인하기

# %%
# 행동 수
print(f'경기 등장 행동 수 : {df_copy["etype"].nunique()}')
# Out:
# 경기 등장 행동 수 : 10

# %%
# 각각의 행동 유형이 얼마나 발생?
df_copy["etype"].value_counts()
# Out:
# shot          13108
# rebound        7971
# free throw     3780
# foul           3417
# sub            2891
# turnover       2261
# timeout         950
# jump ball       131
# violation       114
# ejection          1
# Name: etype, dtype: int64

# %%
fig, ax=plt.subplots(1, 1, figsize=(15, 7), dpi=200)

_=sns.countplot(x=df_copy["etype"], ax=ax)
_=ax.set_ylabel("")
_=ax.set_title("행동 유형 발생 횟수")

# %%
fig, ax=plt.subplots(1, 1, figsize=(8, 5), dpi=200)

_=sns.countplot(y=df_copy["etype"], ax=ax)
_=ax.set_ylabel("")
_=ax.set_title("행동 유형 발생 횟수")

# %%
# 각 쿼터에서 가장 자주 등장하는 행동
df3=df_copy[["period", "etype"]].groupby(["period", "etype"]).size().reset_index()
df3.columns=["period", "etype", "count"]

# %%
# 이런 경우에 어떻게 해야 할까?
# period 기준으로 count가 max인 행만 골라야 한다. (period는 1 ~ 5)
df3.head(10)
# Out:
#    period       etype  count
# 0       1        foul    665
# 1       1  free throw    666
# 2       1   jump ball     85
# 3       1     rebound   2023
# 4       1        shot   3500
# 5       1         sub    555
# 6       1     timeout    166
# 7       1    turnover    547
# 8       1   violation     25
# 9       2        foul    887

# %%
# pivot
df2=df_copy.groupby(["period", "etype"]).size().reset_index().pivot(columns="period", 
                                                                index="etype", values=0)
df2
# Out:
# period           1       2       3       4     5
# etype
# ejection       NaN     NaN     1.0     NaN   NaN
# foul         665.0   887.0   848.0  1002.0  15.0
# free throw   666.0   944.0   949.0  1205.0  16.0
# jump ball     85.0    16.0     7.0    21.0   2.0
# rebound     2023.0  1966.0  1986.0  1976.0  20.0
# shot        3500.0  3279.0  3232.0  3063.0  34.0
# sub          555.0   915.0   584.0   832.0   5.0
# timeout      166.0   266.0   185.0   327.0   6.0
# turnover     547.0   571.0   533.0   608.0   2.0
# violation     25.0    35.0    27.0    27.0   NaN

# %%
# stack plot 
fig, ax=plt.subplots(1, 1, figsize=(20, 8), dpi=200)
_=df2.plot(kind="bar", stacked=True, ax=ax)
_=ax.legend(fontsize=15)
_=plt.xticks(rotation=0) # 글자 회전
_=ax.set_title("쿼터 별 행동 발생 횟수")
